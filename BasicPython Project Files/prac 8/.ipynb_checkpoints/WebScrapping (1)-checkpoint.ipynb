# %% [markdown]
# # Web scraping
# Web scraping, also called web data mining or web harvesting, is the process of constructing an agent which can extract, parse, download and organize useful information from the web automatically. In other words, we can say that instead of manually saving the data from websites, the web scraping software will automatically load and extract data from multiple websites as per our requirement.

# %% [markdown]
# ![webScrapping.png](attachment:webScrapping.png)

# %% [markdown]
# # Working of a Web Scraper
# Web scraper may be defined as a software or script used to download the contents of multiple web pages and extracting data from it.
# ![wS_working.png](attachment:wS_working.png)

# %% [markdown]
# # The Components of a Web Page
# When we visit a web page, our web browser makes a request to a web server. This request is called a GET request, since we’re getting files from the server. The server then sends back files that tell our browser how to render the page for us. The files fall into a few main types:
#
# HTML — contain the main content of the page.<br>
# CSS — add styling to make the page look nicer.<br>
# JS — Javascript files add interactivity to web pages.<br>
# Images — image formats, such as JPG and PNG allow web pages to show pictures.<br><br>
# After our browser receives all the files, it renders the page and displays it to us. There’s a lot that happens behind the scenes to render a page nicely, but we don’t need to worry about most of it when we’re web scraping. When we perform web scraping, we’re interested in the main content of the web page, so we look at the HTML.

# %% [markdown]
# # HTML example:

# %% [raw]
# <html>
# <head>
# <title> Web Scarapping</title>
# </head>
# <body>
# <p class="bold-paragraph">
# Here's a paragraph of text!
# <a href="https://www.dataquest.io" id="learn-link">Learn Data Science Online</a>
# </p>
# <p class="bold-paragraph extra-large">
# Here's a second paragraph of text!
# <a href="https://www.python.org" class="extra-large">Python</a>
# </p>
# </body>
# </html>

# %% [markdown]
# # The requests library
# The first thing we’ll need to do to scrape a web page is to download the page. We can download pages using the Python requests library. The requests library will make a GET request to a web server, which will download the HTML contents of a given web page for us.

# %%
# http://dataquestio.github.io/web-scraping-pages/simple.html

# %%
import requests
page = requests.get("http://dataquestio.github.io/web-scraping-pages/simple.html")
page
# Out:
# <Response [200]>

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html>\n    <head>\n        <title>A simple example page</title>\n    </head>\n    <body>\n        <p>Here is some simple content for this page.</p>\n    </body>\n</html>'

# %% [markdown]
# # Parsing a page with BeautifulSoup
# As we can see above, we now have downloaded an HTML document.
#
# We can use the BeautifulSoup library to parse this document, and extract the text from the p tag. We first have to import the library, and create an instance of the BeautifulSoup class to parse our document:

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content,'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# </html>>

# %% [markdown]
# As all the tags are nested, we can move through the structure one level at a time. We can first select all the elements at the top level of the page using the children property of soup. Note that children returns a list generator, so we need to call the list function on it:

# %%
soup.children

# %%
list(soup.children)
# Out:
# ['html', '\n', <html>
#  <head>
#  <title>A simple example page</title>
#  </head>
#  <body>
#  <p>Here is some simple content for this page.</p>
#  </body>
#  </html>]

# %% [markdown]
# The above tells us that there are two tags at the top level of the page — the initial <!DOCTYPE html> tag, and the <html> tag. There is a newline character (\n) in the list as well. Let’s see what the type of each element in the list is:

# %%
for item in list(soup.children):
    print(type(item))
# Out:
# <class 'bs4.element.Doctype'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>

# %% [markdown]
# As we can see, all of the items are BeautifulSoup objects. The first is a Doctype object, which contains information about the type of the document. The second is a NavigableString, which represents text found in the HTML document. The final item is a Tag object, which contains other nested tags. The most important object type, and the one we’ll deal with most often, is the Tag object.
#
# The Tag object allows us to navigate through an HTML document, and extract other tags and text.

# %%
print(list(soup.children))
html = list(soup.children)[2]
html
# Out:
# ['html', '\n', <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# </html>]
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# </html>

# %%
list(html.children)
# Out:
# ['\n', <head>
#  <title>A simple example page</title>
#  </head>, '\n', <body>
#  <p>Here is some simple content for this page.</p>
#  </body>, '\n']

# %%
for ele in list(html.children):
    print(ele)
# Out:
# <head>
# <title>A simple example page</title>
# </head>
#
#
# <body>
# <p>Here is some simple content for this page.</p>
# </body>

# %%
list(html.children)[0]
# Out:
# '\n'

# %%
list(html.children)[1]
# Out:
# <head>
# <title>A simple example page</title>
# </head>

# %%
list(html.children)[2]
# Out:
# '\n'

# %%
list(html.children)[3]
# Out:
# <body>
# <p>Here is some simple content for this page.</p>
# </body>

# %%
body = list(html.children)[3]
print(list(body.children))
# Out:
# ['\n', <p>Here is some simple content for this page.</p>, '\n']

# %%
p =  list(body.children)[1]
p
# Out:
# <p>Here is some simple content for this page.</p>

# %%
p.get_text()
# Out:
# 'Here is some simple content for this page.'

# %% [markdown]
# # Finding all instances of a tag at once

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://bongirwarvk.webnode.com/cgngui/'

# %%
r = requests.get(url)
htmlContent =  r.content

# %%
soup = BeautifulSoup(htmlContent, 'html.parser')
soup
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <!--[if IE 8]><html class="lt-ie10 lt-ie9 no-js" prefix="og: https://ogp.me/ns#" lang="en-us"><![endif]--><!--[if IE 9]><html class="lt-ie10 no-js" prefix="og: https://ogp.me/ns#" lang="en-us"><![endif]--><!--[if gt IE 9]><!--><html class="no-js" lang="en-us" prefix="og: https://ogp.me/ns#"><!--<![endif]--><head><meta charset="utf-8"/><link href="https://d1di2lzuh97fh2.cloudfront.net/files/44/442/442wv9.ico?ph=73f0ed939b" rel="shortcut icon"/><link href="https://d1di2lzuh97fh2.cloudfront.net/files/44/442/442wv9.ico?ph=73f0ed939b" rel="apple-touch-icon"/><link href="https://d1di2lzuh97fh2.cloudfront.net/files/44/442/442wv9.ico?ph=73f0ed939b" rel="icon"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><title>Computer Graphics &amp; GUI Design Technologies CST319 :: Bongirwarvk</title><meta content="width=device-width,initial-scale=1,viewport-fit=cover" name="viewport"/><meta content="no" name="msapplication-tap-highlight"/><link href="https://d1di2lzuh97fh2.cloudfront.net/files/30/306/3069bc.css?ph=73f0ed939b" rel="stylesheet"/><link href="https://d1di2lzuh97fh2.cloudfront.net/files/0t/0t6/0t6gfq.css?ph=73f0ed939b" rel="stylesheet"/><link data-wnd_color_scheme_file="" href="https://d1di2lzuh97fh2.cloudfront.net/files/3n/3no/3no2qj.css?ph=73f0ed939b" rel="stylesheet"/><link data-wnd_additive_color_file="" href="https://d1di2lzuh97fh2.cloudfront.net/files/1n/1n3/1n3qrl.css?ph=73f0ed939b" rel="stylesheet"/><link data-wnd_typography_file="" href="https://d1di2lzuh97fh2.cloudfront.net/files/48/483/483g0s.css?ph=73f0ed939b" rel="stylesheet"/><meta content="Computer Graphics &amp;amp; GUI Design Technologies CST319" name="description"/><meta content="" name="keywords"/><meta content="Webnode 2" name="generator"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="black" name="apple-mobile-web-app-status-bar-style"/><meta content="telephone=no" name="format-detection"/>
# <meta content="https://bongirwarvk.webnode.com/cgngui/" property="og:url"/><meta content="Computer Graphics &amp; GUI Design Technologies CST319 :: Bongirwarvk" property="og:title"/><meta content="article" property="og:type"/><meta content="Computer Graphics &amp;amp; GUI Design Technologies CST319" property="og:description"/><meta content="Bongirwarvk" property="og:site_name"/><meta content="https://d1di2lzuh97fh2.cloudfront.net/files/3z/3z3/700/3z3k1i.jpg?ph=73f0ed939b" property="og:image"/><meta content="2019-08-12T00:00:00+0200" property="og:article:published_time"/><meta content="noindex,nofollow" name="robots"/><link href="https://bongirwarvk.webnode.com/cgngui/" rel="canonical"/><script>window.checkAndChangeSvgColor=function(c){try{var a=document.getElementById(c);if(a){c=[["border","borderColor"],["outline","outlineColor"],["color","color"]];for(var h,b,d,f=[],e=0,m=c.length;e<m;e++)if(h=window.getComputedStyle(a)[c[e][1]].replace(/\s/g,"").match(/^rgb[a]?\(([0-9]{1,3}),([0-9]{1,3}),([0-9]{1,3})/i)){b="";for(var g=1;3>=g;g++)b+=("0"+parseInt(h[g],10).toString(16)).slice(-2);"0"===b.charAt(0)&&(d=parseInt(b.substr(0,2),16),d=Math.max(16,d),b=d.toString(16)+b.slice(-4));f.push(c[e][0]+"="+b)}if(f.length){var k=a.getAttribute("data-src"),l=k+(0>k.indexOf("?")?"?":"&")+f.join("&");a.src!=l&&(a.src=l,a.outerHTML=a.outerHTML)}}}catch(n){}};</script><link href="https://use.typekit.net/fqp8gek.css" rel="stylesheet"/><script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 			(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 			m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 			})(window,document,'script','//www.google-analytics.com/analytics.js','ga');ga('create', 'UA-797705-6', 'auto',{"name":"wnd_header"});ga('wnd_header.set', 'dimension1', 'W2');ga('wnd_header.set', 'anonymizeIp', true);ga('wnd_header.send', 'pageview');</script></head><body class="l l-01 layout-01 not-short-content wt-blog-sidebar c-s-n l-sidebar wt-blog ac-i b-btn-r b-btn-s-l b-btn-dn b-btn-bw-1 img-d-n img-t-o img-h-z line-solid b-e-ds lbox-d c-s-n wnd-fe" data-layout-type="sidebar">
# <div class="wnd-page cs-gray ac-amber">
# <div class="l-w cf t-30" id="wrapper">
# <header class="l-h cf" id="header">
# <div class="section-wrapper cf">
# <div class="section-wrapper-content cf"><div class="s section header header-01 cf design-06 sc-m wnd-background-pattern" wn-border="bottom" wn-border-element="section">
# <div class="header-wrapper header-fixed cf wnd-fixed">
# <div class="section-bg s-bg">
# <div class="section-bg-layer wnd-background-pattern bgpos-center-center" style="background-image:url('https://d1di2lzuh97fh2.cloudfront.net/files/0s/0s8/0s8gu2.png?ph=73f0ed939b')">
# </div>
# <div class="section-bg-layer section-bg-overlay"></div>
# </div>
# <div class="section-inner">
# <div class="nav-line initial-state cf">
# <div class="logoblock">
# <div class="logo logo-borders playfair-display wnd-image-vector">
# <div class="logo-content">
# <a href="/home/">
# <div class="logo-embed">
# <div class="logo-embed-cell">
# <embed data-src="https://d1di2lzuh97fh2.cloudfront.net/files/3g/3g3/3g3es4.svg?ph=73f0ed939b" id="wnd_LogoBlock_379717_img" type="image/svg+xml"/><script>checkAndChangeSvgColor('wnd_LogoBlock_379717_img');</script></div>
# </div>
# <div class="logo-text">
# <span class="logo-text-cell"></span>
# </div>
# </a>
# </div>
# </div>
# <div class="subclaim">
# <span class="inline-text">
# <span class="link">Prof. Vrushali Bongirwar</span>
# </span>
# </div>
# </div>
# <div class="cartblock">
# </div>
# <div id="menu-mobile">
# <a href="#" id="menu-submit"><span></span>Menu</a>
# </div>
# <div id="menublock">
# <nav class="centered" data-align="centered" data-type="vertical" id="menu" role="navigation">
# <div class="menu-font menu-wrapper">
# <a class="close-menu" href="#" rel="nofollow">
# <span>Close Menu</span>
# </a>
# <ul class="level-1"><li class="wnd-homepage">
# <a class="menu-item" href="/home/"><span class="menu-item-text">Homepage</span></a>
# </li><li>
# <a class="menu-item" href="/wat/"><span class="menu-item-text">Web Architecture &amp; Technologies CST 413-1</span></a>
# </li><li class="wnd-active wnd-active-path">
# <a class="menu-item" href="/cgngui/"><span class="menu-item-text">Computer Graphics &amp; GUI Design Technologies CST319</span></a>
# </li><li>
# <a class="menu-item" href="/csp319/"><span class="menu-item-text">CSP319</span></a>
# </li><li>
# <a class="menu-item" href="/pps/"><span class="menu-item-text">PPS</span></a>
# </li><li>
# <a class="menu-item" href="/publications/"><span class="menu-item-text">Publications</span></a>
# </li><li>
# <a class="menu-item" href="/contact/"><span class="menu-item-text">Contact </span></a>
# </li>
# </ul><span class="more-text">More</span>
# </div>
# </nav>
# </div>
# <script type="application/javascript">var el=document.getElementById("menu");"undefined"!=typeof el&&(el.style.display="none")</script>
# </div>
# </div>
# </div>
# </div></div>
# </div>
# </header><div id="content">
# <main class="l-m cf" id="main" role="main">
# <div class="section-wrapper cf">
# <div class="section-wrapper-content cf"><section class="s section heading-02 design-07 sc-m wnd-background-image"><div class="section-bg s-bg">
# <div class="section-bg-layer wnd-background-image fx-none bgpos-top-center bgatt-scroll" style="background-image:url('https://d1di2lzuh97fh2.cloudfront.net/files/3z/3z3/450/3z3k1i.jpg?ph=73f0ed939b')">
# </div>
# <div class="section-bg-layer section-bg-overlay overlay-black-light"></div>
# </div>
# <div class="section-inner">
# <div class="content">
# <div class="heading-table">
# <div class="heading-table-cell">
# <h1 class="heading-claim auto-font-size"><span class="styled-inline-text claim-default playfair-display">
# <span><span></span></span>
# </span></h1>
# </div>
# </div>
# </div>
# </div>
# </section><section class="s section padding-up-down blog-01 design-01 sc-w"><div class="section-bg s-bg">
# <div class="section-bg-layer">
# </div>
# <div class="section-bg-layer section-bg-overlay"></div>
# </div>
# <div class="section-inner">
# <div class="content ez cf wnd-no-cols">
# <div class="ez-c">
# <div class="b b-text cf">
# <div class="b-c b-text-c b-s b-s-t60 b-s-b60 cf"><h1>Computer Graphics &amp; GUI Design Technologies CST319</h1>
# <h3>Text<br/>
#  </h3>
# </div>
# </div><div class="blog blog-left-thumbnail thumb-bg thumb-float no-grid b b-s cf">
# <div class="blog-wrapper cf">
# <div class="blog-container cf">
# <article class="item"><div class="item-wrapper">
# <div class="item-media"><a href="/l/charmtown-feast/"><div class="thumbnail wnd-orientation-portrait" id="wnd_ThumbnailBlock_2sko57">
# <img alt="" height="272" src="https://bongirwarvk.webnode.com/_files/200000005-f06e8f167c/200/cg1.jpg" width="185"/><div class="thumbnail-bg">
# <div class="thumbnail-bg-layer wnd-background-image" style="background-image:url('https://bongirwarvk.webnode.com/_files/200000005-f06e8f167c/450/cg1.jpg')">
# </div>
# <div class="thumbnail-bg-layer thumbnail-bg-overlay"></div>
# </div>
# </div></a></div>
# <div class="item-content">
# <div class="item-head">
# <h2><a href="/l/charmtown-feast/"><div class="listing-data">
# <span>CST319</span>
# </div></a></h2>
# <div class="item-date"><div class="listing-data">
# <span>08/09/2019</span>
# </div></div>
# </div>
# <div class="item-perex"><div class="perex">
# <div class="perex-content"><p>Computer Graphics</p></div>
# </div></div>
# </div>
# </div>
# </article><article class="item"><div class="item-wrapper">
# <div class="item-media"><a href="/l/opening-ceremony/"><div class="thumbnail wnd-orientation-landscape" id="wnd_ThumbnailBlock_79hftf">
# <img alt="" height="203" src="https://bongirwarvk.webnode.com/_files/200000009-4c32a4d2c4/200/images.jpg" width="248"/><div class="thumbnail-bg">
# <div class="thumbnail-bg-layer wnd-background-image" style="background-image:url('https://bongirwarvk.webnode.com/_files/200000009-4c32a4d2c4/450/images.jpg')">
# </div>
# <div class="thumbnail-bg-layer thumbnail-bg-overlay"></div>
# </div>
# </div></a></div>
# <div class="item-content">
# <div class="item-head">
# <h2><a href="/l/opening-ceremony/"><div class="listing-data">
# <span>CST319</span>
# </div></a></h2>
# <div class="item-date"><div class="listing-data">
# <span>08/05/2019</span>
# </div></div>
# </div>
# <div class="item-perex"><div class="perex">
# <div class="perex-content"><p>CST319</p></div>
# </div></div>
# </div>
# </div>
# </article></div>
# </div>
# <div class="blog-empty-listing"></div>
# </div>
# </div>
# </div>
# </div>
# </section></div>
# </div>
# </main><footer class="section header header-01 cf design-06 sc-m wnd-background-pattern" id="footer" wn-border="top" wn-border-element="footer-line"><div class="footer-container footer-font">
# <div class="footer-line cf">
# <div class="footer-texts">
# <div class="lang-select cf">
# </div>
# <div class="system-footer cf"><span class="sf">
# <span class="sf-content link">Powered by <a href="https://us.webnode.com?utm_source=text&amp;utm_medium=footer&amp;utm_campaign=free1&amp;utm_content=wnd2" rel="nofollow" target="_blank">Webnode</a></span>
# </span></div>
# </div>
# </div>
# </div>
# </footer><script type="application/javascript">!function(){"classList"in document.createElement("_")&&document.body.classList.contains("wnd-cms")===!1&&""===document.getElementsByClassName("sf-content")[0].innerHTML.trim()&&""===document.getElementsByClassName("lang-select")[0].innerHTML.trim()&&document.getElementsByTagName("footer")[0].classList.add("footer-empty")}(),function(){if(0==document.getElementsByClassName("wnd-cms").length)for(var e=document.getElementsByClassName("column-content"),t=0;t<e.length;t++){var s=e[t].querySelector("div"),n=s.getElementsByClassName("b-text-c");void 0!=n[0]&&s.firstChild==s.lastChild&&""===n[0].innerText&&(e[t].classList?e[t].classList.add("column-empty"):(e[t].classList?e[t].classList.contains("column-empty"):new RegExp("\\bcolumn-empty\\b").test(e[t].className))&&(e[t].className+=" column-empty"))}}()</script></div>
# </div>
# </div>
# <div id="wnd_footer"><style type="text/css">#wnd_footer {display: block; box-sizing: border-box; text-align: center; overflow: hidden; overflow-wrap: break-word; word-wrap: break-word; word-break: break-word; position: relative; width: 100%; font-family: Arial, Roboto, Helvetica, sans-serif; font-weight: normal; font-style: normal; font-size: 15px; line-height: 1.5; background-color: rgba(0, 0, 0, 0.7);}#wnd_footer a {color: #fff; text-decoration: none; display: inline-block;}#wnd_footer_left {width: 100%;}#wnd_footer_left_wrapper {padding: 12px 12px 6px;}#wnd_footer_right {width: 100%;}#wnd_footer_right_wrapper {padding: 6px 12px 14px;}#wnd_footer_logo {background: url(https://d1di2lzuh97fh2.cloudfront.net/client/img/wnd-logo2.svg?ph=73f0ed939b) no-repeat; display: inline-block; width: 103px; height: 20px; opacity: .83;}#wnd_footer_logo b {opacity: 0;}@media only screen and (min-width: 480px) {#wnd_footer_left {float: left; min-height: 60px; width: auto; display: table;}#wnd_footer_left_wrapper {text-align: left; padding: 8px 160px 8px 12px; display: table-cell; vertical-align: middle;}#wnd_footer_right {position: absolute; top: 0; left: auto; right: 12px; bottom: 0; width: auto;}#wnd_footer_right_wrapper {text-align: right; padding: 19px 0;}}@media only screen and (min-width: 768px) {#wnd_footer_left_wrapper {padding: 16px 160px 16px 20px;}#wnd_footer_right {right: 20px;}}@media only screen and (min-width: 1200px) {#wnd_footer_left_wrapper {padding-left: 30px;}#wnd_footer_right {right: 30px;}}@media print {#wnd_footer style {display: none !important;}}</style><div id="wnd_footer_left"><div id="wnd_footer_left_wrapper"><a href="https://us.webnode.com?utm_source=text&amp;utm_medium=footer&amp;utm_campaign=free1&amp;utm_content=wnd2" rel="nofollow" target="_blank">Create a free website</a></div></div><div id="wnd_footer_right"><div id="wnd_footer_right_wrapper"><a href="https://us.webnode.com?utm_source=button&amp;utm_medium=footer&amp;utm_campaign=free1&amp;utm_content=wnd2" id="wnd_footer_logo" rel="nofollow" target="_blank"><b>Webnode</b></a></div></div></div><script src="https://d1di2lzuh97fh2.cloudfront.net/files/2s/2sr/2srr0r.js?ph=73f0ed939b" type="text/javascript"></script><script crossorigin="anonymous" src="https://d1di2lzuh97fh2.cloudfront.net/client.fe/js.compiled/lang.en-us.256.js?ph=73f0ed939b"></script><script crossorigin="anonymous" src="https://d1di2lzuh97fh2.cloudfront.net/client.fe/js.compiled/compiled.multi.2-788.js?ph=73f0ed939b"></script><script>var wnd = wnd || {};wnd.$data = {"image_content_items":{"wnd_ThumbnailBlock_206236":{"id":"wnd_ThumbnailBlock_206236","type":"wnd.pc.ThumbnailBlock"},"wnd_Section_heading_260566":{"id":"wnd_Section_heading_260566","type":"wnd.pc.Section"},"wnd_ThumbnailBlock_2sko57":{"id":"wnd_ThumbnailBlock_2sko57","type":"wnd.pc.ThumbnailBlock"},"wnd_ThumbnailBlock_79hftf":{"id":"wnd_ThumbnailBlock_79hftf","type":"wnd.pc.ThumbnailBlock"},"wnd_HeaderSection_header_326992":{"id":"wnd_HeaderSection_header_326992","type":"wnd.pc.HeaderSection"},"wnd_LogoBlock_379717":{"id":"wnd_LogoBlock_379717","type":"wnd.pc.LogoBlock"}},"svg_content_items":{"wnd_LogoBlock_379717":{"id":"wnd_LogoBlock_379717","type":"wnd.pc.LogoBlock"}},"content_items":[],"project_info":{"isMultilanguage":false,"eshop_tax_enabled":"1","country_code":"","contact_state":"","eshop_tax_type":"VAT","eshop_discounts":false}};</script><script>wnd.$system = {"filesPath":"https:\/\/bongirwarvk.webnode.com\/_files\/","staticFiles":"https:\/\/d1di2lzuh97fh2.cloudfront.net\/files","isCms":false,"staticCDNServers":["https:\/\/d1di2lzuh97fh2.cloudfront.net\/"],"fileUploadAllowExtension":["jpg","jpeg","png","gif","bmp","ico","svg","webp","tiff","pdf","doc","docx","ppt","pptx","pps","ppsx","odt","xls","xlsx","txt","rtf","mp3","wma","wav","ogg","amr","flac","m4a","3gp","avi","wmv","mov","mpg","mkv","mp4","mpeg","m4v","swf","gpx","stl","csv","xml","txt","dxf","dwg","iges","igs","step","stp"],"maxUserFormFileLimit":4194304,"frontendL ...
# >

# %%
title= soup.title
print(type(soup.title))
title
# Out:
# <class 'bs4.element.Tag'>
# <title>Computer Graphics &amp; GUI Design Technologies CST319 :: Bongirwarvk</title>

# %%
page = soup.find_all('p')
page
# Out:
# [<p>Computer Graphics</p>, <p>CST319</p>]

# %%
page = soup.find_all('p')
#print(page)
for ele in page:
    print(ele.get_text())
# Out:
# Computer Graphics
# CST319

# %%
page = soup.find_all('img')
print(page)
for ele in page:
    print(ele.get('src'))
# Out:
# [<img alt="" height="272" src="https://bongirwarvk.webnode.com/_files/200000005-f06e8f167c/200/cg1.jpg" width="185"/>, <img alt="" height="203" src="https://bongirwarvk.webnode.com/_files/200000009-4c32a4d2c4/200/images.jpg" width="248"/>]
# https://bongirwarvk.webnode.com/_files/200000005-f06e8f167c/200/cg1.jpg
# https://bongirwarvk.webnode.com/_files/200000009-4c32a4d2c4/200/images.jpg

# %%
anchor= soup.find_all('a')
anchor
# Out:
# [<a href="/home/">
#  <div class="logo-embed">
#  <div class="logo-embed-cell">
#  <embed data-src="https://d1di2lzuh97fh2.cloudfront.net/files/3g/3g3/3g3es4.svg?ph=73f0ed939b" id="wnd_LogoBlock_379717_img" type="image/svg+xml"/><script>checkAndChangeSvgColor('wnd_LogoBlock_379717_img');</script></div>
#  </div>
#  <div class="logo-text">
#  <span class="logo-text-cell"></span>
#  </div>
#  </a>,
#  <a href="#" id="menu-submit"><span></span>Menu</a>,
#  <a class="close-menu" href="#" rel="nofollow">
#  <span>Close Menu</span>
#  </a>,
#  <a class="menu-item" href="/home/"><span class="menu-item-text">Homepage</span></a>,
#  <a class="menu-item" href="/wat/"><span class="menu-item-text">Web Architecture &amp; Technologies CST 413-1</span></a>,
#  <a class="menu-item" href="/cgngui/"><span class="menu-item-text">Computer Graphics &amp; GUI Design Technologies CST319</span></a>,
#  <a class="menu-item" href="/csp319/"><span class="menu-item-text">CSP319</span></a>,
#  <a class="menu-item" href="/pps/"><span class="menu-item-text">PPS</span></a>,
#  <a class="menu-item" href="/publications/"><span class="menu-item-text">Publications</span></a>,
#  <a class="menu-item" href="/contact/"><span class="menu-item-text">Contact </span></a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000019-59f6d59f6f/Perl_part_1 and_2.ppt" target="_blank">
#  <span class="b-btn-t">DOWNLOAD Perl_...nd_2.ppt</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000020-23e6723e69/Proxy_and_NAT.ppt" target="_blank">
#  <span class="b-btn-t">DOWNLOAD Proxy..._NAT.ppt</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000021-1d9541d956/www_and_CGI.ppt" target="_blank">
#  <span class="b-btn-t">DOWNLOAD www_and_CGI.ppt</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000022-e98fee9900/crryptography1.pptx" target="_blank">
#  <span class="b-btn-t">DOWNLOAD crry...phy1.pptx</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000025-9342b9342d/DiiffiHelman_DigitalSignature.pptx" target="_blank">
#  <span class="b-btn-t">DOWNLOAD Diif...ture.pptx</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000032-bbf38bbf3a/crryptography2.pptx" target="_blank">
#  <span class="b-btn-t">DOWNLOAD crry...phy2.pptx</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000033-ac66cac66d/Intranet_Extranet.ppt" target="_blank">
#  <span class="b-btn-t">DOWNLOAD Intra...anet.ppt</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000034-bd8f2bd8f4/multimedia stream _IP telephony.pptx" target="_blank">
#  <span class="b-btn-t">DOWNLOAD mult...hony.pptx</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000035-dc555dc557/Unit-6 Part-1 Web_arch.pptx" target="_blank">
#  <span class="b-btn-t">DOWNLOAD Unit...arch.pptx</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000036-8f3b78f3b8/E-commerce_updated.pdf" target="_blank">
#  <span class="b-btn-t">DOWNLOAD E-com...ated.pdf</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000031-c337cc337f/WAT Assignment 1_Section B.pdf" target="_blank">
#  <span class="b-btn-t">DOWNLOAD WAT A...on B.pdf</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000023-23f6e23f70/SolutionT.docx" target="_blank">
#  <span class="b-btn-t">DOWNLOAD SolutionT.docx</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000026-1b0d51b0d7/test 1_WAT 18-19.doc" target="_blank">
#  <span class="b-btn-t">DOWNLOAD test ...8-19.doc</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000027-4862a4862b/test 2_WAT 18-19.doc" target="_blank">
#  <span class="b-btn-t">DOWNLOAD test ...8-19.doc</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000028-e2d38e2d3a/Test 1.docx" target="_blank">
#  <span class="b-btn-t">DOWNLOAD Test 1.docx</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000029-0c7950c797/T2.docx" target="_blank">
#  <span class="b-btn-t">DOWNLOAD T2.docx</span>
#  </a>,
#  <a class="b-btn-l" href="https://bongirwarvk.webnode.com/_files/200000030-8520b8520c/T3.docx" target="_blank">
#  <span class="b-btn-t">DOWNLOAD T3.docx</span>
#  </a>,
#  <a href="https://us.webnode.com?utm_source=text&amp;utm_medium=footer&amp;utm_campaign=free1&amp;utm_content=wnd2" rel="nofollow" target="_blank">Webnode</a>,
#  <a href="https://us.webnode.com?utm_source=text&amp;utm_medium=footer&amp;utm_campaign=free1&amp;utm_content=wnd2" rel="nofollow" target="_blank">Create a free website</a>,
#  <a href="https://us.webnode.com?utm_source=button&amp;utm_medium=footer&amp;utm_campaign=free1&amp;utm_content=wnd2" id="wnd_footer_logo" rel="nofollow" target="_blank"><b>Webnode</b></a>]

# %%
links=set()
for link in soup.find_all('a'):
    links.add(link.get('href')) #append(link.get('href'))
links
# Out:
# {'#',
#  '/cgngui/',
#  '/contact/',
#  '/csp319/',
#  '/home/',
#  '/pps/',
#  '/publications/',
#  '/wat/',
#  'https://us.webnode.com?utm_source=button&utm_medium=footer&utm_campaign=free1&utm_content=wnd2',
#  'https://us.webnode.com?utm_source=text&utm_medium=footer&utm_campaign=free1&utm_content=wnd2'}

# %%
QUESTIONS
Implement web scrapping 
Web page 
https://bongirwarvk.webnode.com/wat/
    
    Find out all links
    find text
    find images
    find how many times Test/assignment/lecture word is appeared on to the page
    find which words are there with its frequency store it in a dictionary
