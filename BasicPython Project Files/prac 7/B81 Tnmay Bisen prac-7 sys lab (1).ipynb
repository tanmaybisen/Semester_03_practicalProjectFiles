# %%
# Q1) Load the Automobile data from a given csv file into a dataframe and print the 
# shape of the data, type of the data and first and last 4 rows  (Automobile_data.csv)

# Q2) Replace the abnormal symbols i.e. ?? , ## to null value i.e. NaN  

import os
os.chdir("C:/Users/RASHU/Downloads")

import pandas as pd
d= pd.read_csv("Automobile_data.csv",na_values=["?"])
df = pd.DataFrame(d)
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
print(df.shape)
# Out:
# (205, 26)

# %%
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
df.head(4)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0      111.0
# 1          130         mpfi  3.47    2.68               9.0      111.0
# ...

# %%
df.tail(4)
# Out:
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 201         -1               95.0  volvo       gas      turbo         four
# 202         -1               95.0  volvo       gas        std         four
# 203         -1               95.0  volvo    diesel      turbo         four
# 204         -1               95.0  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 201         mpfi  3.78    3.15               8.7      160.0    5300.0
# 202         mpfi  3.58    2.87               8.8      134.0    5500.0
# ...

# %%
# Q3) Describe the dataset, and find the number of observations, missing values and nan values.

df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          35.442168    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  201.000000  201.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.273539    0.316717
# ...

# %%
x,y=df.shape
print("{} are total no of observation".format(x*y))
# Out:
# 5330 are total no of observation

# %%
print("Missing values and NaN values are :")
print(df.isnull().sum())
# Out:
# Missing values and NaN values are :
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# Q4) View basic statistical details like percentile, mean, std deviation, mode, variance, skewness and kutosis of Automobile data                                       

import pandas 

dataset = pandas.read_csv("Automobile_data.csv",na_values=["?",0])
dataset = {'%tile':dataset.quantile(),'MEAN':dataset.mean(),'Standard deviation':dataset.std(),'MODE':dataset.mode(),'VAR':dataset.var(),'SKEW':dataset.skew(),'KURT':dataset.kurt(),'MEDIAN':dataset.median(),'Count-Result':dataset.count()}       
df = pandas.DataFrame(dataset)
print(df)
# Out:
#                       %tile          MEAN  Standard deviation  \
# aspiration              NaN           NaN                 NaN
# body-style              NaN           NaN                 NaN
# bore                   3.31      3.329751            0.273539
# city-mpg              24.00     25.219512            6.542142
# compression-ratio      9.00     10.142537            3.972040
# curb-weight         2414.00   2555.565854          520.680204
# drive-wheels            NaN           NaN                 NaN
# engine-location         NaN           NaN                 NaN
# engine-size          120.00    126.907317           41.642693
# engine-type             NaN           NaN                 NaN
# fuel-system             NaN           NaN                 NaN
# fuel-type               NaN           NaN                 NaN
# height                54.10     53.724878            2.443522
# highway-mpg           30.00     30.751220            6.886443
# ...

# %%
# Q5) Find the most expensive car company name

import pandas
data = pd.read_csv("Automobile_data.csv",na_values=["?",0])
val=data[['make','price']][data.price==data['price'].max()]
print(val)
# Out:
#              make    price
# 74  mercedes-benz  45400.0

# %%
# Q6) Print all Toyata cars available

import pandas

data1 = pd.read_csv("Automobile_data.csv")
data1=data1[data1['make']=="toyota"]
print(data1)
# Out:
#      symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 150          1                87  toyota       gas        std          two
# 151          1                87  toyota       gas        std          two
# 152          1                74  toyota       gas        std         four
# 153          0                77  toyota       gas        std         four
# 154          0                81  toyota       gas        std         four
# 155          0                91  toyota       gas        std         four
# 156          0                91  toyota       gas        std         four
# 157          0                91  toyota       gas        std         four
# 158          0                91  toyota    diesel        std         four
# 159          0                91  toyota    diesel        std         four
# 160          0                91  toyota       gas        std         four
# ...

# %%
# Q7)  Find each company’s highest price car
data = pandas.read_csv("Automobile_data.csv",na_values=["?",0])
company = data.groupby('make')
h_price = company['make','price'].max()
print(h_price)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   after removing the cwd from sys.path.
#                         make    price
# make
# alfa-romero      alfa-romero  16500.0
# audi                    audi  23875.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge  12964.0
# honda                  honda  12945.0
# isuzu                  isuzu  11048.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mercury              mercury  16503.0
# mitsubishi        mitsubishi  14869.0
# nissan                nissan  19699.0
# peugot                peugot  18150.0
# plymouth            plymouth  12764.0
# porsche              porsche  37028.0
# renault              renault   9895.0
# ...

# %%
# Q8)  Find the average mileage of each car making company

import pandas

data = pandas.read_csv("Automobile_data.csv",na_values=["?",0])
company = data.groupby('make')
avg_m = company['make','city-mpg'].mean()
print(avg_m)
# Out:
#                 city-mpg
# make
# alfa-romero    20.333333
# audi           18.857143
# bmw            19.375000
# chevrolet      41.000000
# dodge          28.000000
# honda          30.384615
# isuzu          31.000000
# jaguar         14.333333
# mazda          25.705882
# mercedes-benz  18.500000
# mercury        19.000000
# mitsubishi     24.923077
# nissan         27.000000
# peugot         22.454545
# plymouth       28.142857
# porsche        17.400000
# renault        23.000000
# saab           20.333333
# subaru         26.333333
# toyota         27.500000
# volkswagen     28.583333
# volvo          21.181818
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   import sys

# %%
# Q9)  Sort all cars by price column

import pandas 
data = pandas.read_csv("Automobile_data.csv",na_values=["?",0])
data = data.sort_values(by=['price'], ascending=True)
print(data)
# Out:
#      symboling  normalized-losses           make fuel-type aspiration  \
# 138        2.0               83.0         subaru       gas        std
# 18         2.0              121.0      chevrolet       gas        std
# 50         1.0              104.0          mazda       gas        std
# 150        1.0               87.0         toyota       gas        std
# 76         2.0              161.0     mitsubishi       gas        std
# ..         ...                ...            ...       ...        ...
# 74         1.0                NaN  mercedes-benz       gas        std
# 9          NaN                NaN           audi       gas      turbo
# 44         1.0                NaN          isuzu       gas        std
# 45         NaN                NaN          isuzu       gas        std
# 129        1.0                NaN        porsche       gas        std
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
# Q10) Create the horrizontal barplot for Automobile dataset

import pandas 
data = pandas.read_csv("Automobile_data.csv",na_values=["?",0])
data.plot.barh(stacked=True)

# %%
# Q11) Create a pair plot.

import pandas
import  seaborn as sns
data = pandas.read_csv("Automobile_data.csv",na_values=["?",0])
sns.pairplot(data)

# %%
# Q12) Print correlation matrix for this Automobile dataset and show heatmap
import pandas
import seaborn as sns
data = pandas.read_csv("Automobile_data.csv",na_values=["?",0])
recieved=data.corr()
print(recieved)
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.593821   -0.606250 -0.335226
# normalized-losses   0.593821           1.000000   -0.074362  0.023220
# wheel-base         -0.606250          -0.074362    1.000000  0.874587
# length             -0.335226           0.023220    0.874587  1.000000
# width              -0.251113           0.105073    0.795144  0.841118
# height             -0.552581          -0.432335    0.589435  0.491029
# curb-weight        -0.193617           0.119893    0.776386  0.877728
# engine-size        -0.069980           0.167365    0.569329  0.683360
# bore               -0.075296          -0.036167    0.490378  0.607480
# stroke             -0.074828           0.065627    0.161477  0.129739
# compression-ratio  -0.191953          -0.132654    0.249786  0.158414
# horsepower          0.080443           0.295772    0.352297  0.555003
# ...

# %%
sns.heatmap(recieved,annot=True)
